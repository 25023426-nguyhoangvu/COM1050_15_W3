# %% [markdown]
# #BÀI 1:

# %%
def swap():
    a, b = map(int, input("Enter 2 numbers: ").split(", "))
               
    a = a^b
    b = a^b
    a = a^b

    print(a, b)

swap()
# Out:
# Enter 2 numbers:  2, 3
# 3 2

# %% [markdown]
# W3A3

# %%
try:
    number = int(input("Enter a number: "))
    if (number & (number - 1) == 0):
        print(f"{number} là bội của 2")
except:
    print("Invalid")

# %% [markdown]
# W3A4

# %%
import math
m,n=map(int,input().split()) 
print('kết quả phép chia làm tròn xuống là:',math.floor(m/n))

# %% [markdown]
# W3A5

# %%
import math
m,n=map(int,input().split()) 
print('kết quả phép chia làm tròn lên là:',math.ceil(m/n))

# %% [markdown]
# W3A6

# %%
x=int(input('nhập số')) 
if x>=0: 
    if x%2==0: 
       print('Even') 
    else: 
       print('Odd') 
else: print('nhập lại số dương')

# %%
W3A7

# %%
a=int(input('nhập số a:')) 
b=int(input('Nhập số b:')) 
if a<0 and b<0: 
    print('Yes') 
else: 
    print('No')
# Out:
# nhập số a: 3
# Nhập số b: 6
# No

# %% [markdown]
# W3A8

# %%
a,b=map(str,input('nhập 2 chuỗi cách bởi dấu cách:').split()) 
if len(a)>len(b):
    print('True') 
else: print('False')

# %%
W3A9

# %%
a,b,c=map(int,input('Nhập độ dài 3 cạnh').split()) 
if a>0 and b>0 and c>0 :  
   if (a+b)>c and (a+c)>b and (b+c)>a: 
      print('Yes') 
   else: 
      print('No') 
else: print('Độ dài cạnh là số dương')

# %% [markdown]
# W3A10

# %%
a,b,c,d=map(int,input('Nhập 4 số bởi dấu cách').split()) 
max_=max(a,b,c,d) 
print(f'số lớn nhất là {max_}')

# %% [markdown]
# W3A11

# %%
a,b,c=map(int,input('Nhập độ dài 3 cạnh').split()) 
if a>0 and b>0 and c>0 :  
   if (a+b)>c and (a+c)>b and (b+c)>a: 
      if a==b==c: 
          print('Tam giác đều') 
      elif a==b!=c or b==c!=a or c==a!=b: 
          print('Tam giác cân') 
      else: 
          print('Tam giác thường') 
   else: 
      print('Không phải tam giác') 
else: print('Độ dài cạnh là số dương')

# %% [markdown]
# W3A12

# %%
n=int(input('Đây là năm:')) 
if (n%4==0 and n%100!=0) or n%400==0: 
    print(f'{n} là năm nhuận') 
else: 
    print(f'{n} không là năm nhuận')

# %%
W3A13
